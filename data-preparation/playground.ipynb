# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
debts = pd.read_csv("raw_debts_log_04.csv")

# %%
debts
# Out:
#     user_id        date   party  amount  \
# 0         2  2024-08-30   Marah      -1
# 1         2  2025-07-08  Raghad       9
# 2         2  2025-07-06   Marah       3
# 3         2  2025-04-17   Marah      -8
# 4         2  2025-08-18  Samyah     -18
# 5         2  2025-03-15   Marah     -17
# 6         2  2024-08-27    Omar     -19
# 7         2  2024-08-19    Omar      33
# 8         2  2024-06-20  Samyah       0
# 9         2  2024-11-13    Omar     -20
# 10        2  2025-08-24  Samyah      38
# 11        2  2025-06-14  Raghad      17
# 12        2  2024-04-20   Marah      -2
# 13        2  2024-06-07  Samyah      18
# 14        2  2024-07-15   Marah     -13
# 15        2  2024-01-07  Raghad     -15
# 16        2  2025-06-10  Raghad      39
# 17        2  2024-03-05  Samyah     -19
# 18        2  2025-05-12    Omar       8
# 19        2  2025-08-11  Raghad      13
# 20        2  2025-06-02  Samyah      12
# 21        2  2025-03-10   Marah      38
# 22        2  2024-08-19    Omar      31
# 23        2  2024-07-21  Raghad      37
# 24        2  2025-06-23  Raghad      -3
# 25        2  2024-12-30  Raghad      39
# 26        2  2025-05-20    Omar      36
# 27        2  2024-10-28   Marah      39
# 28        2  2024-09-05    Omar       0
# 29        2  2025-03-17  Samyah      31
# 30        2  2024-03-06  Samyah      26
# 31        2  2024-09-15    Omar     -14
# 32        2  2025-06-09  Samyah       9
# 33        2  2025-01-20    Omar      -5
# 34        2  2025-06-18  Samyah     -20
# 35        2  2025-06-19  Raghad      31
# 36        2  2025-06-20  Raghad     -13
# 37        2  2024-10-16  Samyah      33
# 38        2  2024-08-27  Raghad     -15
# 39        2  2024-03-04    Omar      16
# 40        2  2025-05-25  Samyah      -3
# 41        2  2025-02-09   Marah      37
# 42        2  2024-11-02  Raghad     -17
# 43        2  2025-04-11  Samyah     -12
# 44        2  2025-04-18  Raghad      21
# 45        2  2025-03-30   Marah      14
# 46        2  2024-09-14  Samyah     -20
# 47        2  2025-04-04  Raghad      -8
# 48        2  2025-07-30  Raghad      -5
# 49        2  2024-07-03  Samyah      13
#
#                                                 notes      type
# 0                                                 NaN  Recieved
# 1                                                 NaN  Recieved
# 2                   In hac habitasse platea dictumst.  Recieved
# 3                                                 NaN  Recieved
# 4   Morbi sem mauris, laoreet ut, rhoncus aliquet,...  Recieved
# 5                                Suspendisse potenti.  Recieved
# 6                   Nullam porttitor lacus at turpis.  Recieved
# 7                                                 NaN  Recieved
# 8   Vestibulum ante ipsum primis in faucibus orci ...  Recieved
# 9                                                 NaN  Recieved
# 10                     Fusce posuere felis sed lacus.  Recieved
# 11                                   Fusce consequat.  Recieved
# 12                                                NaN  Recieved
# 13                                                NaN  Recieved
# 14                                  Praesent blandit.  Recieved
# 15                                                NaN  Recieved
# 16                                                NaN  Recieved
# 17                                                NaN  Recieved
# 18                                                NaN  Recieved
# 19  Vestibulum ante ipsum primis in faucibus orci ...  Recieved
# 20                                      Sed sagittis.  Recieved
# 21                                                NaN  Recieved
# 22                                                NaN  Recieved
# 23                                                NaN  Recieved
# 24                                                NaN  Recieved
# 25                                        Nulla nisl.  Recieved
# 26                                                NaN  Recieved
# 27                 Maecenas tincidunt lacus at velit.  Recieved
# 28                                                NaN  Recieved
# 29                                                NaN  Recieved
# 30                                                NaN  Recieved
# 31                                                NaN  Recieved
# 32                                                NaN  Recieved
# 33                            Pellentesque eget nunc.  Recieved
# 34                      Nam tristique tortor eu pede.  Recieved
# 35  In est risus, auctor sed, tristique in, tempus...  Recieved
# 36  Quisque id justo sit amet sapien dignissim ves...  Recieved
# 37                                                NaN  Recieved
# 38  Integer aliquet, massa id lobortis convallis, ...  Recieved
# 39                                                NaN  Recieved
# 40                              Mauris sit amet eros.  Recieved
# 41                                                NaN  Recieved
# 42                                Phasellus in felis.  Recieved
# 43                               Suspendisse potenti.  Recieved
# 44                                                NaN  Recieved
# 45  Vestibulum quam sapien, varius ut, blandit non...  Recieved
# 46                                                NaN  Recieved
# 47                                                NaN  Recieved
# 48                                                NaN  Recieved
# 49       Donec ut mauris eget massa tempor convallis.  Recieved

# %%
debts.groupby("party")["amount"].sum()
# Out:
# party
# Marah      90
# Omar       66
# Raghad    130
# Samyah     88
# Name: amount, dtype: int64

# %%
inv1 = pd.read_csv("raw_investments_log_01.csv")
inv2 = pd.read_csv("raw_investments_log_02.csv")

# %%
inv1
# Out:
#      user_id        date  change  \
# 0          1  2024-11-30      69
# 1          1  2024-12-19     -52
# 2          1  2024-12-21     -20
# 3          1  2025-05-22     -22
# 4          1  2024-11-05     -53
# ..       ...         ...     ...
# 595        1  2025-08-18      70
# 596        1  2025-08-24      -2
# 597        1  2025-07-05       6
# 598        1  2024-12-04      44
# 599        1  2025-01-14      10
#
#                                                  notes
# 0    Integer aliquet, massa id lobortis convallis, ...
# 1    Integer pede justo, lacinia eget, tincidunt eg...
# 2                                                  NaN
# 3                               Aliquam erat volutpat.
# 4                      Cras pellentesque volutpat dui.
# ..                                                 ...
# 595                                                NaN
# 596     Maecenas ut massa quis augue luctus tincidunt.
# 597                                                NaN
# 598            Ut at dolor quis odio consequat varius.
# 599                                          Sed ante.
#
# [600 rows x 4 columns]

# %%
inv1["change"].sum()
# Out:
# np.int64(2495)
